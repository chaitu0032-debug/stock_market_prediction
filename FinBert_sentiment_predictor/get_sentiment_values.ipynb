# %%
import pandas as pd

# %%
df1 = pd.read_csv("TATAMOTORS.csv")
df2 = pd.read_csv("new_big_upadted.csv")

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df2['Date'] = pd.to_datetime(df2['Date'])
df2
# Out:
#       Unnamed: 0       Date  \
# 0              0 2020-05-26
# 1              1 2020-05-25
# 2              2 2020-05-24
# 3              3 2020-05-23
# 4              4 2020-05-22
# ...          ...        ...
# 4900        4900 2006-09-26
# 4901        4901 2006-09-25
# 4902        4902 2006-09-23
# 4903        4903 2006-09-22
# 4904        4904 2006-09-21
#
#                                                   Title    score1    score2
# 0     ATMs to become virtual bank branches, accept d...   neutral   neutral
# 1     Huge scam in YES Bank for many years, says Enf...   neutral  positive
# 2     Bank of Maharashtra sanctioned Rs 2,789 cr in ...   neutral   neutral
# 3     DCB Bank's profit before tax declines 37.6% to...  negative   neutral
# 4     Retail, MSME loans to get cheaper as RBI cuts ...   neutral  positive
# ...                                                 ...       ...       ...
# 4900  Interest rates softening: SBI.RBI to finalise ...   neutral   neutral
# ...

# %%
df3 = df2[::-1].reset_index()
df4 = df3.drop(["index","Unnamed: 0"],axis = 1)
df3 = df4
df3
# Out:
#            Date                                              Title    score1  \
# 0    2006-09-21  LIC to raise solvency margin by Rs 7,000cr.Viz...   neutral
# 1    2006-09-22  Banks cut retail loan rates ahead of fest seas...   neutral
# 2    2006-09-23  Terror cover eludes festivals.Loan rate cuts a...   neutral
# 3    2006-09-25  Vijaya Bank to raise Rs 900cr, eyes buyout.Con...   neutral
# 4    2006-09-26  Interest rates softening: SBI.RBI to finalise ...   neutral
# ...         ...                                                ...       ...
# 4900 2020-05-22  Retail, MSME loans to get cheaper as RBI cuts ...   neutral
# 4901 2020-05-23  DCB Bank's profit before tax declines 37.6% to...  negative
# 4902 2020-05-24  Bank of Maharashtra sanctioned Rs 2,789 cr in ...   neutral
# 4903 2020-05-25  Huge scam in YES Bank for many years, says Enf...   neutral
# 4904 2020-05-26  ATMs to become virtual bank branches, accept d...   neutral
#
#         score2
# 0      neutral
# ...

# %%
df1["score1"] = "neutral"
df1["score2"] = "neutral"

# %%
df1
# Out:
#            Date      Symbol Series  Prev Close    Open    High     Low  \
# 0    2000-01-03       TELCO     EQ      201.60  207.40  217.25  207.40
# 1    2000-01-04       TELCO     EQ      216.75  217.00  219.00  206.00
# 2    2000-01-05       TELCO     EQ      208.20  194.00  217.80  194.00
# 3    2000-01-06       TELCO     EQ      213.25  215.00  229.90  215.00
# 4    2000-01-07       TELCO     EQ      222.10  224.00  239.90  223.10
# ...         ...         ...    ...         ...     ...     ...     ...
# 5199 2020-11-23  TATAMOTORS     EQ      169.10  169.50  173.90  165.55
# 5200 2020-11-24  TATAMOTORS     EQ      170.70  171.85  175.50  171.10
# 5201 2020-11-25  TATAMOTORS     EQ      172.05  175.00  176.80  169.25
# 5202 2020-11-26  TATAMOTORS     EQ      171.45  171.60  175.00  171.05
# 5203 2020-11-27  TATAMOTORS     EQ      173.75  174.65  183.85  174.65
#
#         Last   Close    VWAP     Volume      Turnover    Trades  \
# ...

# %%
for index in range(len(df1)):
    date = df1.loc[index,"Date"]
    cor_idx = df3.index[df3["Date"] == date]
    if(len(cor_idx) != 0):
        df1.loc[index,"score1"] = df3.loc[cor_idx[0],"score1"]
        df1.loc[index,"score2"] = df3.loc[cor_idx[0],"score2"]

# %%
x = df3.loc[0,"Date"]

# %%
x
# Out:
# Timestamp('2006-09-21 00:00:00')

# %%
y = df3.loc[len(df3)-1,"Date"]

# %%
y
# Out:
# Timestamp('2020-05-26 00:00:00')

# %%
df1["Date"]
# Out:
# 0      2000-01-03
# 1      2000-01-04
# 2      2000-01-05
# 3      2000-01-06
# 4      2000-01-07
#           ...
# 5199   2020-11-23
# 5200   2020-11-24
# 5201   2020-11-25
# 5202   2020-11-26
# 5203   2020-11-27
# Name: Date, Length: 5204, dtype: datetime64[ns]

# %%
star_idx = df1[df1["Date"] == x].index[0]
end_idx = df1[df1["Date"] == y].index[0]

# %%
star_idx
end_idx
# Out:
# 5071

# %%
df1_new = df1[star_idx:end_idx+1]
df1_new
# Out:
#            Date      Symbol Series  Prev Close    Open    High     Low  \
# 1689 2006-09-21  TATAMOTORS     EQ      842.25  869.80  869.80  838.20
# 1690 2006-09-22  TATAMOTORS     EQ      847.45  846.90  846.90  833.25
# 1691 2006-09-25  TATAMOTORS     EQ      835.80  838.00  857.40  838.00
# 1692 2006-09-26  TATAMOTORS     EQ      847.65  850.00  859.60  846.35
# 1693 2006-09-27  TATAMOTORS     EQ      857.95  860.10  866.50  850.00
# ...         ...         ...    ...         ...     ...     ...     ...
# 5067 2020-05-19  TATAMOTORS     EQ       80.65   82.50   85.65   81.50
# 5068 2020-05-20  TATAMOTORS     EQ       81.80   81.25   84.40   80.70
# 5069 2020-05-21  TATAMOTORS     EQ       83.45   83.10   85.20   82.90
# 5070 2020-05-22  TATAMOTORS     EQ       84.10   83.40   83.90   82.00
# 5071 2020-05-26  TATAMOTORS     EQ       82.80   83.90   85.70   82.60
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
df1_new.to_csv("Tata_motors_new.csv")
