# %%
import pandas as pd

# %%
df1 = pd.read_csv("ADANIPORTS.csv")

# %%
df2 = pd.read_csv('compressed_2.csv')

# %%
df1['Date'] = pd.to_datetime(df1['Date'])
df1
# Out:
#            Date      Symbol Series  Prev Close    Open     High     Low  \
# 0    2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1    2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2    2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3    2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4    2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...         ...         ...    ...         ...     ...      ...     ...
# 3215 2020-11-23  ADANIPORTS     EQ      375.85  375.85   379.35  370.30
# 3216 2020-11-24  ADANIPORTS     EQ      375.15  378.00   402.00  376.00
# 3217 2020-11-25  ADANIPORTS     EQ      392.25  396.30   404.70  384.40
# 3218 2020-11-26  ADANIPORTS     EQ      398.95  400.80   413.00  395.65
# 3219 2020-11-27  ADANIPORTS     EQ      410.15  411.00   416.00  408.20
#
#         Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2
# Out:
#      Unnamed: 0       Date                                              Title  \
# 0             0 2020-05-26  ATMs to become virtual bank branches, accept d...
# 1             1 2020-05-25  Huge scam in YES Bank for many years, says Enf...
# 2             2 2020-05-24  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 3             3 2020-05-23  DCB Bank's profit before tax declines 37.6% to...
# 4             4 2020-05-22  Retail, MSME loans to get cheaper as RBI cuts ...
# ..          ...        ...                                                ...
# 486         486 2019-01-04  Dues owed by wilful defaulters to PSBs double ...
# 487         487 2019-01-03  Sebi issues another show-cause notice to NSEL ...
# 488         488 2019-01-02  Swap ratio fixed for Bank of Baroda merger wit...
# 489         489 2019-01-01  A call for timely action.New RBI norm allows o...
# 490         490 2018-12-31  Asset Reconstruction Companies to scale up ope...
#
#        score1    score2
# ...

# %%
 df3 = df2[::-1].reset_index()

# %%
df4 = df3.drop(["index","Unnamed: 0"],axis = 1)

# %%
df3 = df4

# %%
df3
# Out:
#           Date                                              Title    score1  \
# 0   2018-12-31  Asset Reconstruction Companies to scale up ope...  positive
# 1   2019-01-01  A call for timely action.New RBI norm allows o...   neutral
# 2   2019-01-02  Swap ratio fixed for Bank of Baroda merger wit...   neutral
# 3   2019-01-03  Sebi issues another show-cause notice to NSEL ...  negative
# 4   2019-01-04  Dues owed by wilful defaulters to PSBs double ...  negative
# ..         ...                                                ...       ...
# 486 2020-05-22  Retail, MSME loans to get cheaper as RBI cuts ...   neutral
# 487 2020-05-23  DCB Bank's profit before tax declines 37.6% to...  negative
# 488 2020-05-24  Bank of Maharashtra sanctioned Rs 2,789 cr in ...   neutral
# 489 2020-05-25  Huge scam in YES Bank for many years, says Enf...   neutral
# 490 2020-05-26  ATMs to become virtual bank branches, accept d...   neutral
#
#        score2
# 0     neutral
# 1     neutral
# ...

# %%
df3["High"] = -100
df3["Low"] = -100
df3["VWAP"] = -100
df3["Turnover"] = -100

# %%
df3
# Out:
#           Date                                              Title    score1  \
# 0   2018-12-31  Asset Reconstruction Companies to scale up ope...  positive
# 1   2019-01-01  A call for timely action.New RBI norm allows o...   neutral
# 2   2019-01-02  Swap ratio fixed for Bank of Baroda merger wit...   neutral
# 3   2019-01-03  Sebi issues another show-cause notice to NSEL ...  negative
# 4   2019-01-04  Dues owed by wilful defaulters to PSBs double ...  negative
# ..         ...                                                ...       ...
# 486 2020-05-22  Retail, MSME loans to get cheaper as RBI cuts ...   neutral
# 487 2020-05-23  DCB Bank's profit before tax declines 37.6% to...  negative
# 488 2020-05-24  Bank of Maharashtra sanctioned Rs 2,789 cr in ...   neutral
# 489 2020-05-25  Huge scam in YES Bank for many years, says Enf...   neutral
# 490 2020-05-26  ATMs to become virtual bank branches, accept d...   neutral
#
#        score2  High  Low  VWAP  Turnover
# ...

# %%
for index in range(len(df3)):
    date = df3.loc[index,"Date"]
    cor_idx = df1.index[df1["Date"] == date]
    if(len(cor_idx) != 0):
        df3.loc[index,"High"] = df1.loc[cor_idx[0],"High"]
        df3.loc[index,"Low"] = df1.loc[cor_idx[0],"Low"]
        df3.loc[index,"VWAP"] = df1.loc[cor_idx[0],"VWAP"]
        df3.loc[index,"Turnover"] = df1.loc[cor_idx[0],"Turnover"]

# %%
# Out:
#   File "<ipython-input-372-9bea354aceb0>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
indexNames = df3[(df3['High'] == -100) ].index

# %%
df3.drop(indexNames , inplace=True)

# %%
df3["High"] == -100
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 483    False
# 484    False
# 485    False
# 486    False
# 490    False
# Name: High, Length: 339, dtype: bool

# %%
df3
# Out:
#           Date                                              Title    score1  \
# 0   2018-12-31  Asset Reconstruction Companies to scale up ope...  positive
# 1   2019-01-01  A call for timely action.New RBI norm allows o...   neutral
# 2   2019-01-02  Swap ratio fixed for Bank of Baroda merger wit...   neutral
# 3   2019-01-03  Sebi issues another show-cause notice to NSEL ...  negative
# 4   2019-01-04  Dues owed by wilful defaulters to PSBs double ...  negative
# ..         ...                                                ...       ...
# 483 2020-05-19  PSBs report sharp rise in deposits thanks to Y...  negative
# 484 2020-05-20  Govt to use RBI money to support struggling NB...   neutral
# 485 2020-05-21  Covid-19: Banking slippages may rise by Rs 5.5...  negative
# 486 2020-05-22  Retail, MSME loans to get cheaper as RBI cuts ...   neutral
# 490 2020-05-26  ATMs to become virtual bank branches, accept d...   neutral
#
#        score2    High     Low    VWAP      Turnover
# ...

# %%
df3.to_csv("small_new.csv")

# %%
len(df3)
# Out:
# 339

# %%
df10 = pd.read_csv("small_new.csv")

# %%
df10
# Out:
#      Unnamed: 0        Date  \
# 0             0  2018-12-31
# 1             1  2019-01-01
# 2             2  2019-01-02
# 3             3  2019-01-03
# 4             4  2019-01-04
# ..          ...         ...
# 334         483  2020-05-19
# 335         484  2020-05-20
# 336         485  2020-05-21
# 337         486  2020-05-22
# 338         490  2020-05-26
#
#                                                  Title    score1    score2  \
# 0    Asset Reconstruction Companies to scale up ope...  positive   neutral
# 1    A call for timely action.New RBI norm allows o...   neutral   neutral
# 2    Swap ratio fixed for Bank of Baroda merger wit...   neutral   neutral
# 3    Sebi issues another show-cause notice to NSEL ...  negative   neutral
# 4    Dues owed by wilful defaulters to PSBs double ...  negative  negative
# ..                                                 ...       ...       ...
# 334  PSBs report sharp rise in deposits thanks to Y...  negative   neutral
# ...
